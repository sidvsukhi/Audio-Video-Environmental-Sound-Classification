# %% [markdown]
# # Working with Terms and Documents
#
# This first homework assignment starts off with term statistics computations and graphing. In the final section (for CS6200 students), you collect new documents to experiment with.
#
# Read through this Jupyter notebook and fill in the parts marked with `TODO`.

# %% [markdown]
# ## Sample Data
#
# Start by looking at some sample data. We donwload the counts of terms in documents for the first one million tokens of a newswire collection.

# %%
# !wget -O ap201001.json.gz https://github.com/dasmiq/cs6200-hw1/blob/main/ap201001.json.gz?raw=true
# !gunzip ap201001.json.gz
# Out:
# --2022-09-30 21:56:10--  https://github.com/dasmiq/cs6200-hw1/blob/main/ap201001.json.gz?raw=true
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/dasmiq/cs6200-hw1/raw/main/ap201001.json.gz [following]
# --2022-09-30 21:56:10--  https://github.com/dasmiq/cs6200-hw1/raw/main/ap201001.json.gz
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dasmiq/cs6200-hw1/main/ap201001.json.gz [following]
# --2022-09-30 21:56:10--  https://raw.githubusercontent.com/dasmiq/cs6200-hw1/main/ap201001.json.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2854711 (2.7M) [application/octet-stream]
# Saving to: ‘ap201001.json.gz’
#
# ap201001.json.gz    100%[===================>]   2.72M  --.-KB/s    in 0.07s
#
# 2022-09-30 21:56:10 (40.9 MB/s) - ‘ap201001.json.gz’ saved [2854711/2854711]

# %% [markdown]
# We convert this file with one JSON record on each line to a list of dictionaries.

# %%
import json
rawfile = open('ap201001.json')
terms = [json.loads(line) for line in rawfile]

# %% [markdown]
# Here are the first ten records, showing the count of each term for each document and field. In this dataset, field only takes the values `body` or `title`.

# %%
terms[1:10]
# Out:
# [{'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'about', 'count': 1},
#  {'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'abuse', 'count': 1},
#  {'id': 'APW_ENG_20100101.0001',
#   'field': 'body',
#   'term': 'academy',
#   'count': 1},
#  {'id': 'APW_ENG_20100101.0001',
#   'field': 'body',
#   'term': 'accused',
#   'count': 2},
#  {'id': 'APW_ENG_20100101.0001',
#   'field': 'body',
#   'term': 'actress',
#   'count': 1},
#  {'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'ad', 'count': 1},
#  {'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'after', 'count': 1},
#  {'id': 'APW_ENG_20100101.0001',
#   'field': 'body',
#   'term': 'agenda',
#   'count': 1},
#  {'id': 'APW_ENG_20100101.0001',
#   'field': 'body',
#   'term': 'agreed',
#   'count': 1}]

# %% [markdown]
# Each record has four fields:
# * `id`, with the identifier for the document;
# * `field`, with the region of the document containing a given term;
# * `term`, with the lower-cased term; and
# * `count`, with the number of times each term occurred in that field and document.

# %% [markdown]
# ## Computing Term Statistics

# %% [markdown]
# If we look at the most frequent terms for a given document, we mostly see common function words, such as `the`, `and`, and `of`. Start exploring the dataset by computing some of these basic term statistics. You can make your life easier using data frame libraries such as `pandas`, core python libraries such as `collections`, or just simple list comprehensions.
#
# Feel free to define helper functions in your code before computing the statistics we're looking for.

# %%
# TODO: Print the 6 terms from document APW_ENG_20100101.0001 with the highest count.
import pandas as pd

data = pd.DataFrame(terms)
#data.head()
data_APW_ENG_20100101_0001 = data[data['id'] == 'APW_ENG_20100101.0001']
data_APW_ENG_20100101_0001.nlargest(6, 'count')
# Out:
#                         id field    term  count
# 0    APW_ENG_20100101.0001  body       a     16
# 192  APW_ENG_20100101.0001  body     the     11
# 15   APW_ENG_20100101.0001  body     and     10
# 34   APW_ENG_20100101.0001  body  brooks     10
# 133  APW_ENG_20100101.0001  body      of     10
# 198  APW_ENG_20100101.0001  body      to     10

# %%
# TODO: Print the 10 terms from all fields of document APW_ENG_20100102.0077 with the highest count.

data_APW_ENG_20100102_0077 = data[data['id'] == 'APW_ENG_20100102.0077']
data_APW_ENG_20100101_0001.nlargest(10, 'count')
# Out:
#                         id field    term  count
# 0    APW_ENG_20100101.0001  body       a     16
# 192  APW_ENG_20100101.0001  body     the     11
# 15   APW_ENG_20100101.0001  body     and     10
# 34   APW_ENG_20100101.0001  body  brooks     10
# 133  APW_ENG_20100101.0001  body      of     10
# 198  APW_ENG_20100101.0001  body      to     10
# 86   APW_ENG_20100101.0001  body      he      9
# 95   APW_ENG_20100101.0001  body      in      9
# 81   APW_ENG_20100101.0001  body   gomez      8
# 74   APW_ENG_20100101.0001  body     for      6

# %%
# TODO: Print the 10 terms with the highest total count in the corpus.

data_count_aggregate = data.groupby('term').sum()
data_count_aggregate = data_count_aggregate.reset_index(level=0)
data_count_aggregate.nlargest(10, 'count')
# Out:
#        term  count
# 24646   the  62216
# 24900    to  26931
# 11865    in  25659
# 0         a  23383
# 16991    of  22326
# 944     and  22125
# 21244  said  10888
# 9269    for   9716
# 17109    on   9382
# 24639  that   8942

# %% [markdown]
# Raw counts may not be the most informative statistic. One common improvement is to use *inverse document frequency*, the inverse of the proportion of documents that contain a given term.

# %%
# TODO: Compute the number of distinct documents in the collection.
N = len(data.id.unique())
print('Number of distinct documents: ', N)

# TODO: Compute the number of distinct documents each term appears in
# and store in a dictionary.
term_document_dict = dict()
term_df = data.groupby("term").agg(id_count = ("id", pd.Series.nunique))
term_df.reset_index()
term_document_dict = dict(zip(term_df.index, term_df.id_count))
print('\nTerm-DocumentCount Dict:\n', term_document_dict)
# Out:
# Number of distinct documents:  2778
#
# Term-DocumentCount Dict:
#  {'a': 2571, 'aaaar': 1, 'aafter': 1, 'aamir': 2, 'aardvarks': 1, 'aare': 1, 'aarhus': 18, 'aaron': 15, 'ab': 12, 'ababa': 6, 'abalone': 1, 'abandon': 18, 'abandoned': 11, 'abandoning': 11, 'abb': 6, 'abbas': 32, 'abbleby': 1, 'abbot': 2, 'abbott': 4, 'abc': 10, "abc's": 6, 'abdel': 17, 'abdellah': 1, 'abdi': 2, 'abdirahman': 1, 'abdolhossein': 1, 'abdomen': 2, 'abdominal': 2, 'abdou': 1, 'abdoulay': 1, 'abdoulaye': 2, 'abducted': 3, 'abducting': 1, 'abductions': 4, 'abdul': 18, 'abdulahi': 2, 'abdulatif': 2, 'abdulla': 6, 'abdullah': 70, 'abdullahi': 2, 'abdulle': 1, 'abdulmutallab': 124, "abdulmutallab's": 51, 'abdulmuttalab': 1, 'abdulzai': 5, 'abdur': 12, 'abe': 10, 'abel': 2, 'abercrombie': 2, 'aberdeen': 2, "aberdeen's": 1, 'abeyance': 1, 'abhisit': 3, 'abide': 2, 'abiding': 1, 'abigail': 1, 'abilities': 2, 'ability': 49, 'ablaze': 5, 'able': 181, 'abn': 2, 'abnormality': 2, 'aboard': 63, 'abolish': 2, 'abolished': 5, 'abolition': 1, 'abort': 4, 'aborted': 1, 'abortion': 3, 'abortions': 1, 'abou': 1, 'aboul': 4, 'aboulafia': 4, 'abounds': 6, 'about': 1077, 'above': 105, 'abraham': 3, 'abrahamson': 1, 'abramovich': 3, 'abreu': 3, 'abroad': 56, 'abrogate': 2, 'abrupt': 5, 'abruptly': 2, 'abruscato': 5, 'abscesses': 1, 'absence': 19, 'absences': 1, 'absent': 5, 'absentia': 7, 'absolute': 15, 'absolutely': 21, 'absorb': 7, 'absorbed': 2, 'absorbing': 2, 'absorbs': 1, 'abstract': 3, 'absurd': 3, 'abu': 86, 'abubakar': 1, 'abudema': 1, "abudema's": 1, 'abudllah': 2, 'abuhatzeira': 3, "abuhatzeira's": 1, 'abuja': 1, 'abundance': 1, 'abuse': 26, 'abused': 11, 'abuser': 1, 'abuses': 16, 'abusing': 4, 'abusive': 4, 'abuts': 1, 'abuzz': 1, 'abyan': 2, 'abysmal': 1, 'ac': 17, 'academic': 3, 'academics': 1, 'academy': 20, "academy's": 1, 'accelerate': 2, 'accelerated': 6, 'accelerating': 3, 'accelerative': 1, 'accelerator': 3, 'accelerometers': 1, 'accent': 2, 'accents': 1, 'accenture': 3, 'accept': 51, 'acceptable': 19, 'acceptance': 10, 'acceptances': 4, 'accepted': 59, 'accepting': 8, 'accepts': 4, 'access': 69, 'accessibility': 1, 'accessible': 2, 'accessing': 6, 'accession': 2, 'accessories': 2, 'accident': 52, 'accidental': 3, 'accidentally': 8, 'accidents': 22, 'acclaimed': 2, 'acclimated': 1, 'acclimatized': 1, 'accommodate': 10, 'accommodations': 1, 'accomodate': 1, 'accompanied': 36, 'accompanies': 2, 'accompany': 2, 'accompanying': 6, 'accomplices': 5, 'accomplish': 9, 'accomplished': 6, 'accomplishment': 1, 'accomplishments': 1, 'accord': 10, 'accordance': 9, 'accorded': 2, 'according': 324, 'accordingly': 3, 'accords': 1, 'accosted': 1, 'account': 82, 'accountability': 9, 'accountable': 9, 'accountant': 4, 'accountants': 1, 'accounted': 3, 'accounting': 24, 'accounts': 62, 'accra': 6, "accra's": 2, 'accrington': 4, 'accumulated': 9, 'accumulating': 3, 'accumulations': 1, 'accumulator': 4, 'accuracy': 3, 'accurate': 11, 'accurately': 6, 'accusation': 4, 'accusations': 8, 'accuse': 13, 'accused': 201, 'accuses': 17, 'accusing': 24, 'accustomed': 3, 'accuweather': 2, 'ace': 11, 'acer': 4, 'aces': 9, 'acetone': 5, 'aches': 2, 'achieve': 13, 'achieved': 16, 'achievement': 9, 'achievements': 5, 'achieves': 2, 'achieving': 3, 'achilles': 12, 'acidic': 1, 'acidity': 1, 'acids': 1, 'acitvist': 2, 'acknowledge': 9, 'acknowledged': 66, 'acknowledges': 6, 'acknowledging': 10, 'acknowledgment': 4, 'acolytes': 1, 'acquaint': 1, 'acquire': 21, 'acquired': 17, 'acquiring': 10, 'acquisition': 26, 'acquisitions': 1, 'acquits': 1, 'acquittal': 1, 'acquitted': 3, 'acre': 19, 'acreage': 1, 'acres': 6, 'acrobatically': 2, 'acronym': 2, 'acronyms': 1, 'across': 221, 'acrylic': 1, 'act': 76, 'acted': 31, 'acting': 40, 'action': 134, 'actions': 92, 'activate': 1, 'activated': 3, 'activating': 1, 'active': 57, 'actively': 6, 'activism': 1, 'activist': 30, "activist's": 2, 'activists': 64, 'activities': 94, 'activity': 137, 'acton': 1, 'actor': 39, 'actors': 8, 'actress': 23, 'actresses': 2, 'acts': 43, 'actual': 40, 'actually': 48, 'acute': 2, 'a ...

# %%
# TODO: Print the relative document frequency of 'the',
# i.e., the number of documents that contain 'the' divided by N.

relative_frequency_the = term_document_dict['the']/N
print('Relative freuency of term "the" is- ', relative_frequency_the)
# Out:
# Relative freuency of term "the" is-  0.9704823614110871

# %% [markdown]
# Empricially, we usually see better retrieval results if we rescale term frequency (within documents) and inverse document frequency (across documents) with the log function. Let the `tfidf` of term _t_ in document _d_ be:
# ```
# tfidf(t, d) = log(count(t, d) + 1) * log(N / df(t))
# ```
#
# Later in the course, we will show a probabilistic derivation of this quantity based on smoothing language models.

# %%
# TODO: Compute the tf-idf value for each term in each document.
# Take the raw term data and add a tfidf field to each record.
import math
tfidf_terms = []

for index, row in data.iterrows():
    tfidf_terms.append(math.log(row['count']+1)*math.log(N/term_document_dict[row['term']]))

data['tfidf'] = tfidf_terms
data.head()
# Out:
#                       id field     term  count     tfidf
# 0  APW_ENG_20100101.0001  body        a     16  0.219394
# 1  APW_ENG_20100101.0001  body    about      1  0.656793
# 2  APW_ENG_20100101.0001  body    abuse      1  3.237961
# 3  APW_ENG_20100101.0001  body  academy      1  3.419818
# 4  APW_ENG_20100101.0001  body  accused      2  2.885155

# %%
# TODO: Print the 20 term-document pairs with the highest tf-idf values.

data.nlargest(20, 'tfidf')
# Out:
#                            id field         term  count      tfidf
# 52727   APW_ENG_20100103.0028  body      guarani     24  23.292878
# 199263  APW_ENG_20100105.0061  body   nomination     95  22.519372
# 234566  APW_ENG_20100105.0446  body      methane     15  21.985205
# 48925   APW_ENG_20100103.0015  body       kheire     14  21.473448
# 192483  APW_ENG_20100105.0014  body    greyhound     14  21.473448
# 433679  APW_ENG_20100107.0036  body  shakespeare     18  21.306960
# 199179  APW_ENG_20100105.0061  body        guild     28  20.667543
# 342740  APW_ENG_20100106.0428  body  shakespeare     16  20.502093
# 21195   APW_ENG_20100102.0197  body      elkhart     12  20.338731
# 305769  APW_ENG_20100106.0075  body        magna     12  20.338731
# 426716  APW_ENG_20100106.1325  body       sutton     20  19.920895
# 107822  APW_ENG_20100104.0043  body        tohti     11  19.704034
# 192485  APW_ENG_20100105.0014  body   greyhounds     11  19.704034
# 430676  APW_ENG_20100107.0018  body        krewe     11  19.704034
# 522469  APW_ENG_20100107.0928  body       minhas     11  19.704034
# 199177  APW_ENG_20100105.0061  body       golden     70  19.302647
# 199053  APW_ENG_20100105.0061  body       actors     26  19.280794
# 430762  APW_ENG_20100107.0018  body       pirate     20  19.241530
# 49706   APW_ENG_20100103.0016  body         punk     13  19.097114
# 113946  APW_ENG_20100104.0108  body      shiites     10  19.014078

# %% [markdown]
# ## Plotting Term Distributions
#
# Besides frequencies and tf-idf values within documents, it is often helpful to look at the distrubitions of word frequencies in the whole collection. In class, we talk about the Zipf distribution of word rank versus frequency and Heaps' Law relating the number of distinct words to the number of tokens.
#
# We might examine these distributions to see, for instance, if an unexpectedly large number of very rare terms occurs, which might indicate noise added to our data.

# %%
# TODO: Compute a list of the distinct words in this collection and sort it in descending order of frequency.
# Thus frequency[0] should contain the word "the" and the count 62216.
frequency = []


data_count_aggregate = data_count_aggregate.sort_values(by=['count'], ascending=False)
frequency = data_count_aggregate.values.tolist()
frequency
# Out:
# [['the', 62216],
#  ['to', 26931],
#  ['in', 25659],
#  ['a', 23383],
#  ['of', 22326],
#  ['and', 22125],
#  ['said', 10888],
#  ['for', 9716],
#  ['on', 9382],
#  ['that', 8942],
#  ['was', 7791],
#  ['is', 6317],
#  ['with', 6283],
#  ['at', 6078],
#  ['he', 5874],
#  ['it', 5357],
#  ['from', 5094],
#  ['as', 4746],
#  ['by', 4641],
#  ['has', 4355],
#  ['an', 4087],
#  ['have', 4012],
#  ['his', 3904],
#  ['be', 3693],
#  ['but', 3638],
#  ['s', 3567],
#  ['u', 3518],
#  ['were', 3478],
#  ['not', 3320],
#  ['are', 3218],
#  ['will', 3063],
#  ['its', 2955],
#  ['who', 2904],
#  ['had', 2900],
#  ['after', 2876],
#  ['year', 2816],
#  ['they', 2423],
#  ['this', 2331],
#  ['new', 2263],
#  ['been', 2241],
#  ['more', 2225],
#  ['two', 2136],
#  ['security', 2097],
#  ['or', 2076],
#  ['which', 2059],
#  ['about', 2003],
#  ['percent', 1966],
#  ['up', 1917],
#  ['their', 1898],
#  ['al', 1897],
#  ['would', 1851],
#  ['also', 1826],
#  ['last', 1807],
#  ['first', 1761],
#  ['than', 1748],
#  ['i', 1722],
#  ['one', 1717],
#  ['other', 1680],
#  ['people', 1678],
#  ['out', 1677],
#  ['government', 1659],
#  ['officials', 1628],
#  ['over', 1626],
#  ['when', 1622],
#  ['we', 1514],
#  ['police', 1497],
#  ['no', 1460],
#  ['into', 1460],
#  ['there', 1402],
#  ['against', 1266],
#  ['because', 1261],
#  ['since', 1244],
#  ['says', 1236],
#  ['time', 1236],
#  ['three', 1221],
#  ['could', 1215],
#  ['wednesday', 1195],
#  ['million', 1187],
#  ['monday', 1179],
#  ['years', 1144],
#  ['some', 1123],
#  ['before', 1107],
#  ['tuesday', 1095],
#  ['yemen', 1069],
#  ['all', 1067],
#  ['she', 1064],
#  ['united', 1058],
#  ['president', 1057],
#  ['her', 1036],
#  ['report', 1014],
#  ['international', 992],
#  ['day', 992],
#  ['while', 984],
#  ['official', 983],
#  ['second', 972],
#  ['down', 965],
#  ['only', 962],
#  ['him', 961],
#  ['if', 946],
#  ['qaida', 942],
#  ['states', 924],
#  ['told', 917],
#  ['world', 916],
#  ['old', 914],
#  ['off', 911],
#  ['attack', 886],
#  ['them', 878],
#  ['through', 868],
#  ['group', 866],
#  ['state', 858],
#  ['intelligence', 846],
#  ['month', 841],
#  ['killed', 839],
#  ['where', 836],
#  ['say', 831],
#  ['including', 820],
#  ['man', 811],
#  ['any', 802],
#  ['so', 790],
#  ['press', 781],
#  ['just', 777],
#  ['now', 776],
#  ['many', 773],
#  ['can', 760],
#  ['billion', 759],
#  ['south', 755],
#  ['still', 754],
#  ['during', 752],
#  ['back', 751],
#  ['high', 751],
#  ['minister', 745],
#  ['former', 742],
#  ['what', 740],
#  ['points', 735],
#  ['most', 735],
#  ['made', 724],
#  ['under', 718],
#  ['obama', 712],
#  ['four', 708],
#  ['thursday', 706],
#  ['country', 703],
#  ['company', 694],
#  ['city', 684],
#  ["it's", 683],
#  ['week', 676],
#  ['between', 675],
#  ['being', 667],
#  ['authorities', 666],
#  ['third', 664],
#  ['home', 663],
#  ['american', 661],
#  ['airport', 650],
#  ['associated', 649],
#  ['statement', 648],
#  ['court', 643],
#  ['top', 640],
#  ['did', 638],
#  ['set', 627],
#  ['sunday', 621],
#  ['national', 611],
#  ['later', 599],
#  ['those', 596],
#  ['us', 593],
#  ['you', 592],
#  ['five', 591],
#  ['rose', 584],
#  ['like', 583],
#  ['cup', 583],
#  ['then', 578],
#  ['several', 575],
#  ['oil', 572],
#  ['such', 572],
#  ['spokesman', 571],
#  ['house', 570],
#  ['season', 566],
#  ['match', 564],
#  ['both', 560],
#  ['game', 557],
#  ['make', 555],
#  ['may', 552],
#  ['afghanistan', 552],
#  ['saturday', 540],
#  ['get', 532],
#  ['expected', 530],
#  ['even', 530],
#  ['take', 522],
#  ['sales', 519],
#  ['british', 515],
#  ['open', 508],
#  ['britain', 507],
#  ['another', 507],
#  ['do', 507],
#  ['won', 506],
#  ['war', 506],
#  ['market', 506],
#  ['december', 506],
#  ['pakistan', 503],
#  ['passengers', 499],
#  ['well', 499],
#  ['left', 498],
#  ['win', 497],
#  ['team', 496],
#  ['washington', 493],
#  ['def', 491],
#  ['six', 490],
#  ['reported', 487],
#  ['cia', 481],
#  ['our', 480],
#  ['public', 478],
#  ['countries', 476],
#  ['according', 471],
#  ['least', 469],
#  ['held', 468],
#  ['go', 468],
#  ['economic', 468],
#  ['information', 468],
#  ['federal', 467],
#  ['based', 467],
#  ['months', 467],
#  ['how', 466],
#  ['called', 460],
#  ['ministry', 460],
#  ['capital', 460],
#  ['should', 459],
#  ['took', 457],
#  ['foreign', 456],
#  ['earlier', 452],
#  ['christmas', 452],
#  ['late', 450],
#  ['lead', 449],
#  ['news', 448],
#  ['militants', 445],
#  ['york', 444],
#  ['contributed', 444],
#  ['service', 443],
#  ['forces', 441],
#  ['failed', 440],
#  ['work', 439],
#  ['north', 437],
#  ['november', 435],
#  ['league', 432],
#  ['part', 430],
#  ['attacks', 429],
#  ['help', 429],
#  ['past', 427],
#  ['family', 426],
#  ['border', 425],
#  ['way', 425],
#  ['area', 425],
#  ['early', 422],
#  ['england', 420],
#  ['saying', 418],
#  ['office', 418],
#  ['chief', 417],
#  ['scored', 415],
#  ['already', 415],
#  ['next', 414],
#  ['military', 413],
#  ['minutes', 412],
#  ['run', 408],
#  ['long', 407],
#  ['led', 405],
#  ['around', 404],
#  ['without', 404],
#  ['end', 404],
#  ['embassy', 403],
#  ['seven', 403],
#  ['added', 403],
#  ['much', 402],
#  ['fell', 402],
#  ['vs', 402],
#  ['however', 401],
#  ['european', 398],
#  ['major', 396],
#  ['bank', 396],
#  ['whether', 395],
#  ['near', 394],
#  ['prices', 394],
#  ['china', 393],
#  ['economy', 389],
#  ['dec', 389],
#  ['yemeni', 388],
#  ['support', 388],
#  ['money', 387],
#  ['place', 387],
#  ['play', 387],
#  ['decision', 385],
#  ['days', 384],
#  ['agency', 383],
#  ['my', 382],
#  ['administration', 378],
#  ['until', 377],
#  ['white', 376],
#  ['among', 373],
#  ['recent', 373],
#  ['came', 373],
#  ["didn't", 372],
#  ['used', 370],
#  ['west', 369],
#  ['jan', 369],
#  ['france', 368],
#  ['final', 368],
#  ['deal', 367],
#  ['use', 366],
#  ['africa', 366],
#  ['program', 363],
#  ['flight', 363],
#  ['condition', 360],
#  ['put', 359],
#  ['aid', 359],
#  ['explosives', 358],
#  ['stock', 357],
#  ['power', 356],
#  ['half', 356],
#  ['dubai', 355],
#  ['local', 354],
#  ['israel', 354],
#  ['case', 353],
#  ['body', 353],
#  ['number', 353],
#  ['show', 352],
#  ['germany', 351],
#  ['iran', 350],
#  ['good', 349],
#  ['weeks', 348],
#  ['eight', 347],
#  ['games', 346],
#  ['officer', 345],
#  ['very', 345],
#  ['going', 342],
#  ['beat', 342],
#  ['leader', 340],
#  ['muslim', 339],
#  ['close', 337],
#  ['abdulmutallab', 336],
#  ['right', 336],
#  ['business', 336],
#  ['site', 334],
#  ['announced', 333],
#  ['own', 333],
#  ['results', 332],
#  ['trying', 332],
#  ['think', 331],
#  ['index', 331],
#  ['died', 330],
#  ['players', 330],
#  ['record', 330],
#  ['meeting', 329],
#  ['region', 328],
#  ['hit', 328],
#  ['suspected', 328],
#  ['lost', 327],
#  ['offer', 326],
#  ['ago', 325],
#  ['too', 324],
#  ['department', 323],
#  ['members', 323],
#  ['list', 322],
#  ['full', 322],
#  ['each', 322],
#  ['death', 321],
#  ['health', 320],
#  ['nearly', 320],
#  ['party', 319],
#  ['bomb', 318],
#  ['plans', 318],
#  ['trading', 318],
#  ['jobs', 315],
#  ['head', 315],
#  ['detroit', 314],
#  ['far', 314],
#  ['russia', 312],
#  ['gaza', 312],
#  ['hours', 312],
#  ['others', 310],
#  ['anti', 309],
#  ['give', 309],
#  ['system', 309],
#  ['following', 309],
#  ['began', 308],
#  ['found', 307],
#  ['point', 306],
#  ['reports', 305],
#  ['markets', 305],
#  ['few', 304],
#  ['test', 304],
#  ['defense', 303],
#  ['key', 302],
#  ['released', 302],
#  ['though', 302],
#  ['men', 302],
#  ['start', 301],
#  ['terror', 301],
#  ['ahead', 300],
#  ['plane', 299],
#  ["country's", 299],
#  ['higher', 298],
#  ['gas', 298],
#  ['jordanian', 298],
#  ['london', 298],
#  ['ap', 298],
#  ['friday', 297],
#  ['law', 296],
#  ['round', 296],
#  ['big', 295],
#  ['workers', 294],
#  ['outside', 294],
#  ['less', 294],
#  ['price', 294],
#  ['see', 294],
#  ['threat', 291],
#  ['explosive', 291],
#  ['analysts', 290],
#  ['need', 289],
#  ['these', 289],
#  ['central', 288],
#  ['terrorist', 288],
#  ['control', 287],
#  ['tv', 286],
#  ["don't", 286],
#  ['b', 285],
#  ['fourth', 285],
#  ['global', 285],
#  ['french', 285],
#  ['behind', 285],
#  ['charges', 285],
#  ['return', 284],
#  ['anonymity', 284],
#  ['australia', 283],
#  ['sea', 283],
#  ['investors', 283],
#  ['arrested', 282],
#  ['bill', 281],
#  ['further', 281],
#  ['keep', 280],
#  ['bound', 280],
#  ['corp', 279],
#  ['gave', 279],
#  ['financial', 279],
#  ['incident', 278],
#  ['prime', 278],
#  ['interest', 277],
#  ['miles', 277],
#  ['killing', 277],
#  ['hamas', 277],
#  ['shot', 276],
#  ['d', 276],
#  ['likely', 276],
#  ['flights', 275],
#  ['comment', 275],
#  ['fight', 275],
#  ['shares', 274],
#  ['director', 273],
#  ['played', 273],
#  ['away', 273],
#  ['move', 273],
#  ['life', 272],
#  ['same', 272],
#  ['air', 272],
#  ['c', 271],
#  ['across', 271],
#  ['john', 271],
#  ['possible', 271],
#  ['screening', 271],
#  ['airlines', 270],
#  ['terrorism', 269],
#  ['tried', 269],
#  ['known', 268],
#  ['companies', 268],
#  ['japanese', 268],
#  ['went', 267],
#  ['western', 266],
#  ['dollar', 265],
#  ['times', 264],
#  ['little', 263],
#  ['overall', 263],
#  ['immediately', 263],
#  ['center', 262],
#  ['accused', 262],
#  ['received', 262],
#  ['continue', 262],
#  ['counterterrorism', 262],
#  ['snow', 262],
#  ['fire', 260],
#  ['efforts', 260],
#  ['kilometers', 260],
#  ['tournament', 259],
#  ['nigerian', 258],
#  ['de', 258],
#  ['troops', 257],
#  ['must', 257],
#  ['leaders', 257],
#  ['egyptian', 257],
#  ['building', 257],
#  ['groups', 257],
#  ['political', 256],
#  ['amp', 256],
#  ['co', 256],
#  ['along', 256],
#  ['better', 256],
#  ['election', 255],
#  ['northwest', 254],
#  ['prison', 253],
#  ['plan', 253],
#  ['david', 253],
#  ['got', 252],
#  ["world's", 252],
#  ['general', 251],
#  ['iraq', 251],
#  ['never', 251],
#  ['want', 250],
#  ['side', 250],
#  ['come', 250],
#  ['food', 249],
#  ['web', 249],
#  ['sent', 248],
#  ['goal', 248],
#  ['might', 248],
#  ['working', 248],
#  ['quarter', 248],
#  ['taliban', 247],
#  ['taken', 247],
#  ['victory', 246],
#  ['spoke', 245],
#  ['attempt', 245],
#  ['manufacturing', 243],
#  ['whose', 243],
#  ['measures', 243],
#  ['senior', 243],
#  ['clear', 242],
#  ['training', 242],
#  ['cash', 242],
#  ['car', 242],
#  ['recovery', 241],
#  ['spain', 240],
#  ['best', 240],
#  ['demand', 240],
#  ['share', 240],
#  ['due', 239],
#  ['province', 239],
#  ['club', 239],
#  ["i'm", 239],
#  ['growth', 239],
#  ['officers', 239],
#  ['inc', 239],
#  ['series', 239],
#  ['southern', 238],
#  ['suspect', 238],
#  ['dead', 238],
#  ['abu', 238],
#  ['closed', 238],
#  ['face', 237],
#  ['level', 237],
#  ['pay', 237],
#  ['helped', 236],
#  ['small', 236],
#  ['october', 236],
#  ['nations', 235],
#  ['egypt', 235],
#  ['water', 235],
#  ['really', 235],
#  ['base', 233],
#  ['airline', 233],
#  ['euro', 233],
#  ['activists', 232],
#  ['east', 231],
#  ['force', 231],
#  ['player', 231],
#  ['writer', 231],
#  ['italy', 231],
#  ['know', 230],
#  ['nine', 230],
#  ['children', 230],
#  ['charged', 230],
#  ['showed', 230],
#  ['total', 230],
#  ['operations', 229],
#  ['data', 228],
#  ['once', 228],
#  ['suicide', 228],
#  ['main', 228],
#  ['nuclear', 228],
#  ['union', 228],
#  ['james', 227],
#  ['march', 226],
#  ['rate', 226],
#  ['me', 225],
#  ['airports', 225],
#  ['stop', 225],
#  ['drug', 224],
#  ['allowed', 224],
#  ['cost', 224],
#  ['media', 224],
#  ['conference', 224],
#  ['chinese', 223],
#  ['straight', 222],
#  ['ordered', 222],
#  ['bomber', 222],
#  ['japan', 222],
#  ['yet', 222],
#  ['europe', 221],
#  ['cuba', 221],
#  ['per', 219],
#  ['n', 219],
#  ['nation', 218],
#  ['net', 217],
#  ['making', 217],
#  ['afghan', 217],
#  ['crude', 215],
#  ['injured', 215],
#  ['issue', 215],
#  ['given', 215],
#  ['february', 215],
#  ['taking', 215],
#  ['energy', 214],
#  ['army', 213],
#  ['pakistani', 213],
#  ['figures', 213],
#  ['bombing', 213],
#  ['democrats', 212],
#  ['board', 212],
#  ['strike', 211],
#  ['agreed', 211],
#  ['rights', 210],
#  ['name', 210],
#  ['situation', 210],
#  ['judge', 210],
#  ['yen', 210],
#  ['again', 210],
#  ['investigation', 210],
#  ['barack', 209],
#  ['enough', 209],
#  ['problems', 209],
#  ['here', 208],
#  ['meet', 208],
#  ['cents', 208],
#  ["year's", 207],
#  ['seconds', 207],
#  ['job', 207],
#  ['tax', 207],
#  ['tour', 206],
#  ['increase', 206],
#  ['become', 206],
#  ['despite', 205],
#  ['does', 205],
#  ['westergaard', 204],
#  ['areas', 204],
#  ['member', 203],
#  ['low', 203],
#  ['line', 203],
#  ['largest', 202],
#  ['private', 201],
#  ['israeli', 201],
#  ['kraft', 201],
#  ['http', 201],
#  ['street', 200],
#  ['field', 199],
#  ['cut', 199],
#  ['leading', 199],
#  ['hospital', 199],
#  ['australian', 199],
#  ['crisis', 198],
#  ['worst', 198],
#  ['northern', 197],
#  ['scanners', 197],
#  ['able', 197],
#  ['talks', 197],
#  ['opening', 196],
#  ['hard', 196],
#  ['spokeswoman', 195],
#  ['cold', 195],
#  ['june', 195],
#  ['future', 195],
#  ['believe', 195],
#  ['seen', 195],
#  ['confirmed', 195],
#  ['violence', 194],
#  ['asked', 194],
#  ['thousands', 194],
#  ['using', 194],
#  ["that's", 193],
#  ['try', 193],
#  ['eu', 192],
#  ['wall', 192],
#  ['moved', 192],
#  ['provide', 192],
#  ['community', 191],
#  ['meters', 191],
#  ['agreement', 191],
#  ['real', 191],
#  ['construction', 190],
#  ['ended', 190],
#  ['spending', 190],
#  ['experts', 190],
#  ['average', 190],
#  ['hundreds', 189],
#  ['night', 189],
#  ['attorney', 189],
#  ['additional', 189],
#  ['weather', 189],
#  ['palestinian', 189],
#  ['services', 189],
#  ['debt', 189],
#  ['opposition', 188],
#  ['declined', 188],
#  ['coming', 188],
#  ['within', 187],
#  ['details', 187],
#  ['ground', 187],
#  ['activity', 187],
#  ['town', 187],
#  ['post', 187],
#  ['feet', 187],
#  ['although', 187],
#  ['met', 187],
#  ['swiss', 186],
#  ['caused', 186],
#  ['latest', 186],
#  ['coach', 186],
#  ['free', 185],
#  ['internet', 184],
#  ['el', 184],
#  ['lot', 184],
#  ['double', 184],
#  ['reached', 184],
#  ['winning', 184],
#  ['finished', 183],
#  ['large', 183],
#  ['recession', 183],
#  ['often', 183],
#  ['wounded', 183],
#  ['leave', 183],
#  ['biggest', 183],
#  ['soldiers', 183],
#  ['include', 183],
#  ['travel', 183],
#  ['mixed', 182],
#  ['islamic', 182],
#  ['paul', 182],
#  ['strong', 182],
#  ['break', 182],
#  ['los', 182],
#  ['exchange', 181],
#  ['looking', 181],
#  ['switzerland', 180],
#  ['employees', 180],
#  ['interior', 180],
#  ['cadbury', 180],
#  ['ball', 180],
#  ['toward', 180],
#  ['irish', 179],
#  ['austria', 179],
#  ['german', 178],
#  ['playing', 178],
#  ['september', 178],
#  ['consumer', 178],
#  ['look', 178],
#  ['india', 178],
#  ['secretary', 177],
#  ['finance', 177],
#  ['parliament', 177],
#  ['order', 177],
#  ['interview', 177],
#  ['johnson', 176],
#  ['brown', 176],
#  ['risk', 176],
#  ['remain', 176],
#  ['hold', 175],
#  ['reporters', 175],
#  ['jordan', 175],
#  ['believed', 175],
#  ['human', 175],
#  ['kill', 175],
#  ['writers', 174],
#  ['senate', 174],
#  ['americans', 174],
#  ['young', 174],
#  ['eastern', 174],
#  ['tribal', 174],
#  ['governments', 173],
#  ['unemployment', 173],
#  ['morning', 173],
#  ['great', 173],
#  ['amid', 173],
#  ['race', 172],
#  ['potential', 172],
#  ['history', 172],
#  ['contract', 172],
#  ['lower', 172],
#  ['appeared', 172],
#  ['clinton', 172],
#  ['threats', 172],
#  ['industry', 171],
#  ['angeles', 171],
#  ['teams', 171],
#  ['included', 171],
#  ['bin', 171],
#  ['reach', 171],
#  ['watch', 170],
#  ['canada', 170],
#  ['january', 170],
#  ['michael', 170],
#  ['turned', 170],
#  ['peace', 170],
#  ['seeking', 170],
#  ['career', 169],
#  ['minute', 169],
#  ['arenas', 169],
#  ['alleged', 169],
#  ['seeded', 169],
#  ['slovak', 169],
#  ["obama's", 168],
#  ['wanted', 168],
#  ['person', 168],
#  ['stage', 168],
#  ['dropped', 168],
#  ['find', 168],
#  ['serious', 168],
#  ['project', 168],
#  ['soon', 168],
#  ['football', 168],
#  ['california', 167],
#  ['balawi', 167],
#  ['room', 167],
#  ['rising', 167],
#  ['claims', 167],
#  ['hand', 167],
#  ['henin', 167],
#  ['loss', 167],
#  ['homes', 167],
#  ['trade', 166],
#  ['authorized', 166],
#  ['technology', 166],
#  ['involved', 166],
#  ['blast', 166],
#  ['development', 165],
#  ['arrest', 165],
#  ['policy', 165],
#  ['parts', 165],
#  ['woman', 165],
#  ['today', 164],
#  ['charge', 164],
#  ['smith', 164],
#  ['school', 164],
#  ['somalia', 164],
#  ['burj', 164],
#  ['university', 164],
#  ['prosecutors', 163],
#  ['anderson', 163],
#  ['claimed', 163],
#  ['stay', 163],
#  ['shooting', 163],
#  ['fired', 162],
#  ['buy', 162],
#  ['signs', 162],
#  ['indian', 162],
#  ['stocks', 161],
#  ['arrived', 161],
#  ['deaths', 161],
#  ['ady', 161],
#  ['strikes', 161],
#  ['provided', 161],
#  ['arab', 161],
#  ['change', 160],
#  ['event', 160],
#  ['tennis', 160],
#  ['safety', 160],
#  ['island', 160],
#  ['singles', 160],
#  ['goals', 160],
#  ["he's", 160],
#  ['care', 159],
#  ['struck', 159],
#  ['republican', 158],
#  ['vehicles', 158],
#  ['credit', 158],
#  ['remains', 158],
#  ['returned', 158],
#  ['rates', 158],
#  ['previous', 158],
#  ['m', 158],
#  ['term', 158],
#  ['barrel', 158],
#  ['review', 157],
#  ['scheduled', 157],
#  ['terms', 157],
#  ['www', 156],
#  ['crew', 156],
#  ['manchester', 156],
#  ['planned', 156],
#  ['almost', 156],
#  ['raised', 155],
#  ['medical', 155],
#  ['detained', 155],
#  ["pakistan's", 155],
#  ['foundation', 155],
#  ['production', 155],
#  ['opened', 154],
#  ['karzai', 154],
#  ['whaling', 154],
#  ['drop', 154],
#  ["government's", 153],
#  ['video', 153],
#  ['rally', 153],
#  ['google', 153],
#  ['nigeria', 153],
#  ['terrorists', 153],
#  ['leaving', 153],
#  ['saudi', 153],
#  ['pressure', 152],
#  ['identified', 152],
#  ['action', 152],
#  ['call', 152],
#  ['guard', 152],
#  ['district', 152],
#  ['operation', 152],
#  ['elections', 152],
#  ['civilian', 152],
#  ['phone', 151],
#  ['fuel', 151],
#  ['concerns', 151],
#  ['speaking', 151],
#  ['dozens', 151],
#  ['america', 150],
#  ['democratic', 150],
#  ['sign', 150],
#  ['meanwhile', 150],
#  ['carried', 150],
#  ['film', 150],
#  ['bag', 150],
#  ['kenya', 150],
#  ['florida', 149],
#  ['visit', 149],
#  ['lawyer', 149],
#  ['changes', 149],
#  ['danish', 148],
#  ['forward', 148],
#  ['growing', 148],
#  ['bring', 148],
#  ['church', 148],
#  ['having', 148],
#  ['luggage', 148],
#  ['running', 148],
#  ['hopes', 148],
#  ['process', 148],
#  ['special', 148],
#  ['com', 148],
#  ['research', 147],
#  ['recently', 147],
#  ['vote', 147],
#  ['republic', 147],
#  ['calls', 147],
#  ['increased', 146],
#  ['champion', 146],
#  ['attempted', 146],
#  ['course', 146],
#  ['khan', 146],
#  ['armed', 146],
#  ['czech', 146],
#  ['airliner', 146],
#  ['standard', 146],
#  ['yards', 146],
#  ['broke', 146],
#  ['stopped', 145],
#  ['considered', 145],
#  ['fifth', 145],
#  ['rules', 145],
#  ['moving', 145],
#  ['rise', 145],
#  ['management', 144],
#  ['natural', 144],
#  ['sector', 144],
#  ['hour', 144],
#  ['embassies', 143],
#  ['ship', 143],
#  ['passenger', 143],
#  ['murder', 143],
#  ['blow', 143],
#  ['somali', 143],
#  ["doesn't", 143],
#  ['analyst', 143],
#  ['port', 143],
#  ['why', 142],
#  ['shepherd', 142],
#  ['mass', 142],
#  ['manager', 142],
#  ['civilians', 142],
#  ['network', 142],
#  ['clash', 142],
#  ['period', 142],
#  ['futures', 142],
#  ['matter', 141],
#  ['role', 141],
#  ['worked', 141],
#  ['palestinians', 141],
#  ["there's", 141],
#  ['thought', 141],
#  ['born', 140],
#  ['every', 140],
#  ['brennan', 140],
#  ...]

# %%
# TODO: Plot a graph of the log of the rank (starting at 1) on the x-axis,
# against the log of the frequency on the y-axis. You may use the matplotlib
# or other library.

import matplotlib.pyplot as plt

plt.plot(math.log(data['tfidf']), math.log(data['count']), label = "line 2")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-efaefa67e6a6> in <module>
#       5 import matplotlib.pyplot as plt
#       6
# ----> 7 plt.plot(math.log(data['tfidf']), math.log(data['count']), label = "line 2")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in wrapper(self)
#     183         if len(self) == 1:
#     184             return converter(self.iloc[0])
# --> 185         raise TypeError(f"cannot convert the series to {converter}")
#     186
#     187     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'float'>

# %%
# TODO: Compute the number of tokens in the corpus.
# Remember to count each occurrence of each word. For instance, the 62,216
# instances of "the" will all count here.
ntokens = 0

# %%
# TODO: Compute the proportion of tokens made up by the top 10 most
# frequent words.

# %%
# TODO: Compute the proportion of tokens made up by the words that occur
# exactly once in this collection.

# %% [markdown]
# ## Acquiring New Documents (for CS6200)
#
# For this assignment so far, you've worked with data that's already been extracted, tokenized, and counted. In this final section, you'll explore acquiring new data.
#
# One common way of acquiring data is through application programming interfaces (APIs) to various databases. The Library of Congress's [_Chronicling America_](https://chroniclingamerica.loc.gov/) site aggregates digitized US newspapers from the past two hundred years, such as the [_Seattle Star_](https://chroniclingamerica.loc.gov/lccn/sn87093407/1922-09-19/ed-1/seq-1/) from 100 years ago.
#
# You can use [the API](https://chroniclingamerica.loc.gov/about/api/) to retrieve JSON data listing all issues of the _Seattle Star_: https://chroniclingamerica.loc.gov/lccn/sn87093407.json
#
# Note the list in the `issues` field. For example, here is the record for the September 19, 1922, issue: https://chroniclingamerica.loc.gov/lccn/sn87093407/1922-09-19/ed-1.json
#
# In that issue record, you'll see records for each page, e.g.: https://chroniclingamerica.loc.gov/lccn/sn87093407/1922-09-19/ed-1/seq-1.json
#
# And inside that page record, you'll see links to data about that page in various data formats, such as JPEG, PDF, and plain text, which is what we want here: https://chroniclingamerica.loc.gov/lccn/sn87093407/1922-09-19/ed-1/seq-1/ocr.txt
#
# This plain text was transcribed from the old page images using optical character recognition (OCR) models, and so contains errors.
#
# Your task is to acquire and analyze the issues of the _Seattle Star_ from the month of September, 1922, i.e., the issues with a date field that starts with `1922-09`. This should be about the same amount of data as the million words from the Associated Press you analyzed in the last section.

# %% [markdown]
# **TODO**: Write code that calls the _Chronicling America_ API to download and extract the text from the _Seattle Star_ from September 1922. You can use the `json` library from above and any other libraries you wish to fetch data from URLs. As you would when working with any production API, you may need to limit your rate of requests.

# %%
# TODO: Data acquisition code here.

# %% [markdown]
# **TODO**: Write code to tokenize the text and count the resulting terms in each document. Since this data comes from automatically transcribing printed pages, some words may be hyphenated across line breaks. There is more than one right way to tokenize this data, so add comments to your code documenting your choices.

# %%
# TODO: Tokenization code here.

# %% [markdown]
# **TODO**: Plot a graph of the log rank against log frequency for your collection, as you did for the sample collection above.

# %%
# TODO: Plotting code here.

# %% [markdown]
# **TODO**: What do you observe about the differences between the distributions of the Associated Press and Seattle Star collections? In this text box, give some possible reasons for these differences.
